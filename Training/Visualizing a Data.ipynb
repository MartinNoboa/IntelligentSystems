# %% [markdown]
# #Connect To Google drive

# %%
from google.colab import drive

drive.mount("/content/gdrive")  
# !pwd
# Out:
# Mounted at /content/gdrive
# /content

# %% [markdown]
# Move to folder

# %%
# %cd "/content/gdrive/MyDrive/Cursos/IA (Sistemas Inteligentes)/English Ene Mayo 2022/Content/1 Intro to AI"
# !ls
# Out:
# /content/gdrive/MyDrive/Cursos/IA (Sistemas Inteligentes)/English Ene Mayo 2022/Content/1 Intro to AI
#  iris.data   'Loading Data set.ipynb'  'Visualizing a Data.ipynb'   wine.names
#  iris.names  'Origins of A.I..gdoc'     wine.data

# %% [markdown]
# # Load Dataset
#
# dataframe (df) is the object where pandas stores the data, each colum is actualy a hash containing the name of the column a as a key and the array of values as the value for the key

# %%
import pandas as pd

#the file has no names for columns.
df = pd.read_csv('iris.data')
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
#we check the names of the columns on the on name file.
df.columns = ["sepal length","sepal width","petal length","petal width", "class"]
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %% [markdown]
# look at the columns

# %%
df_x = df[["sepal length","sepal width","petal length","petal width"]]
df_y = df[["class"]]

# %%
df_x["sepal proportion"] = df_x["sepal width"]/df_x["sepal length"]
df_x["petal proportion"] = df_x["petal width"]/df_x["petal length"]
df_x.head()
# Out:
#    sepal length  sepal width  ...  sepal proportion  petal proportion
# 0           4.9          3.0  ...          0.612245          0.142857
# 1           4.7          3.2  ...          0.680851          0.153846
# 2           4.6          3.1  ...          0.673913          0.133333
# 3           5.0          3.6  ...          0.720000          0.142857
# 4           5.4          3.9  ...          0.722222          0.235294
#
# [5 rows x 6 columns]

# %%
df_y
# Out:
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
#
# [149 rows x 1 columns]

# %% [markdown]
# #Making some nice visuals

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# Scatter plot

# %%
#use variable name to change properties of the plot
df.plot('petal length', 'petal width', kind ='scatter')

# %% [markdown]
# histogram

# %%
df.plot(kind ='hist', alpha = .3)

# %% [markdown]
# line

# %%
df.plot()

# %%
df
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             4.9          3.0           1.4          0.2     Iris-setosa
# 1             4.7          3.2           1.3          0.2     Iris-setosa
# 2             4.6          3.1           1.5          0.2     Iris-setosa
# 3             5.0          3.6           1.4          0.2     Iris-setosa
# 4             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 144           6.7          3.0           5.2          2.3  Iris-virginica
# 145           6.3          2.5           5.0          1.9  Iris-virginica
# 146           6.5          3.0           5.2          2.0  Iris-virginica
# 147           6.2          3.4           5.4          2.3  Iris-virginica
# 148           5.9          3.0           5.1          1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %% [markdown]
# Scatter Matrix

# %%
#tools is no longer in pandas, now you can call pd.plotting directly
pd.plotting.scatter_matrix(df);

# %%
plt.figure()
pd.plotting.parallel_coordinates(df,"class",color=('#556270', '#4ECDC4', '#C7F464'));
