# %% [markdown]
# #Connect To Google drive :)

# %%
from google.colab import drive

drive.mount("/content/gdrive")  
# !pwd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Martin Noboa\Desktop\9 Semestre\AI\Loading Data set.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Martin%20Noboa/Desktop/9%20Semestre/AI/Loading%20Data%20set.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> from google.colab import drive
#       <a href='vscode-notebook-cell:/c%3A/Users/Martin%20Noboa/Desktop/9%20Semestre/AI/Loading%20Data%20set.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> drive.mount("/content/gdrive")
#       <a href='vscode-notebook-cell:/c%3A/Users/Martin%20Noboa/Desktop/9%20Semestre/AI/Loading%20Data%20set.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> get_ipython().system('pwd')
#
# ModuleNotFoundError: No module named 'google'

# %% [markdown]
# Move to folder

# %%
# %cd "/content/gdrive/MyDrive/Cursos/IA (Sistemas Inteligentes)/English Ago Dic 2022/Content/1 Intro to AI"
# !ls
# Out:
# /content/gdrive/MyDrive/Cursos/IA (Sistemas Inteligentes)/English Ago Dic 2022/Content/1 Intro to AI
#  iris.data   'Loading Data set.ipynb'  'Visualizing a Data.ipynb'   wine.names
#  iris.names  'Origins of A.I..gdoc'     wine.data

# %% [markdown]
# # Load Dataset
#
# dataframe (df) is the object where pandas stores the data, each colum is actualy a hash containing the name of the column a as a key and the array of values as the value for the key

# %%
import pandas as pd

#the file has no names for columns.
columns = ["sepal length","sepal width","petal length","petal width", "class"]
df = pd.read_csv('iris.data',names = columns)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Martin Noboa\Desktop\9 Semestre\AI\Loading Data set.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Martin%20Noboa/Desktop/9%20Semestre/AI/Loading%20Data%20set.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/Martin%20Noboa/Desktop/9%20Semestre/AI/Loading%20Data%20set.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> #the file has no names for columns.
#       <a href='vscode-notebook-cell:/c%3A/Users/Martin%20Noboa/Desktop/9%20Semestre/AI/Loading%20Data%20set.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> columns = ["sepal length","sepal width","petal length","petal width", "class"]
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df.columns
# Out:
# Index(['sepal length', 'sepal width', 'petal length', 'petal width', 'class'], dtype='object')

# %% [markdown]
# get a single column you wish

# %%
df["sepal length"]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal length, Length: 150, dtype: float64

# %% [markdown]
# get many columns

# %%
my_df = df[["sepal length","sepal width"]]
my_df
# Out:
#      sepal length  sepal width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %%
df_x = df[["sepal length","sepal width","petal length","petal width"]]
df_y = df[["class"]]

# %%
df_x
# Out:
#      sepal length  sepal width  petal length  petal width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df_y
# Out:
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 1 columns]

# %% [markdown]
# make new columns with indicators

# %%
df_x["sepal proportion"] = df_x["sepal width"]/df_x["sepal length"]
df_x["petal proportion"] = df_x["petal width"]/df_x["petal length"]
df_x.head()
# Out:
#    sepal length  sepal width  ...  sepal proportion  petal proportion
# 0           5.1          3.5  ...          0.686275          0.142857
# 1           4.9          3.0  ...          0.612245          0.142857
# 2           4.7          3.2  ...          0.680851          0.153846
# 3           4.6          3.1  ...          0.673913          0.133333
# 4           5.0          3.6  ...          0.720000          0.142857
#
# [5 rows x 6 columns]
